# %%
import pandas as pd

data = pd.read_csv('titanic3.csv')

data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
data.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female   NaN
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                       Zimmerman, Mr. Leo    male  29.0
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# ...

# %%
# dimensiones, 1309 filas y 14 columnas
data.shape
# Out:
# (1309, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# longitud del dataset
len(data)
# Out:
# 1309

# %%
# estadísticos descriptivos solo de columnas numericas
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# estadisticos descriptivos tanto de columnas numericas como object
data.describe(include='all')
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881135
# std        0.837836     0.486055                   NaN   NaN    14.413500
# min        1.000000     0.000000                   NaN   NaN     0.166700
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
# muestra el tipo de variable por columna
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# muestra la cantidad de tipos de variables por columna
data.nunique()
# Out:
# pclass          3
# survived        2
# name         1307
# sex             2
# age            98
# sibsp           7
# parch           8
# ticket        929
# fare          281
# cabin         186
# embarked        3
# boat           27
# body          121
# home.dest     369
# dtype: int64

# %%
# Muestra la cantidad de tipos de variables deuna determinada columna
data['pclass'].nunique()
# Out:
# 3

# %%
# Muestra nombre de las columnas
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %%
# Selecciona una columna determinada y divide en grupos los valores
data.groupby("sex").size()
# Out:
# sex
# female    466
# male      843
# dtype: int64

# %%
# Crear un subconjunto con filas aleatorias 
sample = data.sample(200) # puedes modificar la cantidad de filas
sample.head()
# Out:
#       pclass  survived                             name     sex   age  sibsp  \
# 726        3         0             Connolly, Miss. Kate  female  30.0      0
# 1040       3         1        Mulvihill, Miss. Bertha E  female  24.0      0
# 1029       3         0              Moran, Mr. Daniel J    male   NaN      1
# 120        1         1     Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 691        3         0  Brocklebank, Mr. William Alfred    male  35.0      0
#
#       parch  ticket     fare cabin embarked boat  body  \
# 726       0  330972   7.6292   NaN        Q  NaN   NaN
# 1040      0  382653   7.7500   NaN        Q   15   NaN
# 1029      0  371110  24.1500   NaN        Q  NaN   NaN
# 120       0   17765  27.7208   D40        C    5   NaN
# 691       0  364512   8.0500   NaN        S  NaN   NaN
#
#                             home.dest
# 726                           Ireland
# 1040                              NaN
# 1029                              NaN
# ...

# %%
sample.shape
# Out:
# (200, 14)

# %%
# Cruzar la informacion de 2 columnas categoricas
pd.crosstab(data['name'], data['sex'])
# Out:
# sex                                            female  male
# name
# Abbing, Mr. Anthony                                 0     1
# Abbott, Master. Eugene Joseph                       0     1
# Abbott, Mr. Rossmore Edward                         0     1
# Abbott, Mrs. Stanton (Rosa Hunt)                    1     0
# Abelseth, Miss. Karen Marie                         1     0
# ...                                               ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       1     0
# van Billiard, Master. James William                 0     1
# van Billiard, Master. Walter John                   0     1
# van Billiard, Mr. Austin Blyler                     0     1
# van Melkebeke, Mr. Philemon                         0     1
#
# [1307 rows x 2 columns]

# %%
# agrupar valores de dos columnas categoricas
data.groupby('name')['sex'].sum()
# Out:
# name
# Abbing, Mr. Anthony                                male
# Abbott, Master. Eugene Joseph                      male
# Abbott, Mr. Rossmore Edward                        male
# Abbott, Mrs. Stanton (Rosa Hunt)                 female
# Abelseth, Miss. Karen Marie                      female
#                                                   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)    female
# van Billiard, Master. James William                male
# van Billiard, Master. Walter John                  male
# van Billiard, Mr. Austin Blyler                    male
# van Melkebeke, Mr. Philemon                        male
# Name: sex, Length: 1307, dtype: object

# %%
# Muestra los datos de una determinada fila
data.iloc[2] # puedes modificar la fila
# Out:
# pclass                                     1
# survived                                   0
# name            Allison, Miss. Helen Loraine
# sex                                   female
# age                                      2.0
# sibsp                                      1
# parch                                      2
# ticket                                113781
# fare                                  151.55
# cabin                                C22 C26
# embarked                                   S
# boat                                     NaN
# body                                     NaN
# home.dest    Montreal, PQ / Chesterville, ON
# Name: 2, dtype: object

# %%
# Muestra los datos de una determinada fila
data.iloc[7:20] # puedes modificar la fila utilizando slicing
# Out:
#     pclass  survived                                               name  \
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# ...

# %%
# Muestra los datos de una determinada fila
data.iloc[7:20] # puedes modificar la fila utilizando slicing
# Out:
#     pclass  survived                                               name  \
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Barras

# %%
sns.countplot(x='sex', data=data)
plt.title("Pasajeros por sexo")
plt.xlabel("Sexo")
plt.ylabel("Cantidad")
plt.show()

# %% [markdown]
# # Histograma

# %%
sns.histplot(data=data, x='age', bins=20, kde=True)
plt.title("Distribución de edad")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# # Dispersion

# %%
sns.scatterplot(data=data, x='age', y='fare')
plt.title("Edad vs Tarifa")
plt.xlabel("Edad")
plt.ylabel("Tarifa")
plt.show()

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='pclass', y='age', data=data)
plt.title("Distribución de edad por clase")
plt.xlabel("Clase")
plt.ylabel("Edad")
plt.show()
